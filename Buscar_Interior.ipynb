# %%
# %pip install pandas
import pandas as pd
import numpy as np

# %%
#Habilitar esta celda para conectar con BBDD en línea
#df1 = pd.read_excel("https://drive.usercontent.google.com/download?id=XXXX", index_col=0)

# %%
#Habiliar esta celda para conectar con BBDD local
df2 = pd.read_csv("products.csv", index_col=0)

# %%
#Habilitar esta celda cuando estén en BBDD columnas adicionales
df2 = df2.drop(['Meta: _unidad_stock', 'Meta: unidad_stock', 'Meta: _rendimiento_m2_por_caja', 'Meta: rendimiento_m2_por_caja', 'Meta: _unidades_por_caja', 'Meta: unidades_por_caja', 'Meta: _precio_unidad_base', 'Meta: precio_unidad_base', 'Meta: _oembed_d045d3fbfd1190a10751dc0e2c648e5e', 'Meta: _oembed_time_d045d3fbfd1190a10751dc0e2c648e5e', 'Meta: _oembed_e10936c53a7a189bcd1df8ea5f315908', 'Meta: _oembed_7c3f32086a09bd825b5719193d813f7d', 'Meta: _oembed_time_7c3f32086a09bd825b5719193d813f7d', 'Meta: _wp_desired_post_slug', 'Meta: _aioseo_og_article_section', 'Meta: _aioseo_title', 'Meta: _aioseo_description'], axis=1)

# %%
df2['Interior'] = df2["Descripción"].str.contains('Interior', regex=True)
df2.head()
# Out:
#                                                     Nombre  \
# SKU
# 2009Oc                      Malla Vidrio 30X30 Ocre A 0028
# 2009Oce                  Malla Vidrio 30X30 Oc‚ano Gml 017
# 2020Bl               Malla Mosaico Blue GMB-2342 4mm 30x30
# 3115     Cerámica Muro Blanco Brillo (Con Engobe) 20x30...
# 3205Be             Cerámica Muro Serrano Beige 25x35(2,22)
#
#                                                Descripción  \
# SKU
# 2009Oc   Formato:30x30mm<br>Dimension Mosaico (piezas):...
# 2009Oce  Formato:30x30mm<br>  Dimension Mosaico (piezas...
# 2020Bl   <h3><p style="color:#d83030;"><b>Código Limatc...
# 3115     <h5 style="color: #ff0000;"><span style="color...
# 3205Be   <h3><p style="color:#ff0000;"><b>Código Limatc...
#
#         Meta: _ficha_tecnica  Meta: ficha_tecnica  \
# SKU
# 2009Oc   field_62a3443dff2ce                  NaN
# 2009Oce  field_62a3443dff2ce                  NaN
# 2020Bl   field_62a3443dff2ce                  NaN
# ...

# %%
df3 = df2[df2.Interior.fillna(False)]
df3["Descripción"] = df3["Descripción"].str.replace("\n", "<br>", regex=False)
# Out:
# /tmp/ipykernel_4354/3630565701.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3 = df2[df2.Interior.fillna(False)]
# /tmp/ipykernel_4354/3630565701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Descripción"] = df3["Descripción"].str.replace("\n", "<br>", regex=False)

# %%
#df2.to_excel('ANTIDESLIZANTE_SI/NO_ELIMINAR.xlsx', index=True)

# %%
df2.to_csv('Interior.csv', encoding='utf-8-sig', index=True)

# %%
# %pip install pandas
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
df1 = pd.read_excel("https://drive.usercontent.google.com/download?id=", index_col=1)
# Out:
#                                                      Title  \
# SKU
# 2009Oc                      Malla Vidrio 30X30 Ocre A 0028
# 2009Oce                  Malla Vidrio 30X30 Oc‚ano Gml 017
# 2020Bl               Malla Mosaico Blue GMB-2342 4mm 30x30
# 3115     Cerámica Muro Blanco Brillo (Con Engobe) 20x30...
# 3205Be             Cerámica Muro Serrano Beige 25x35(2,22)
#
#                                                    Content  \
# SKU
# 2009Oc   Formato:30x30mm<br>Dimension Mosaico (piezas):...
# 2009Oce  Formato:30x30mm<br>  Dimension Mosaico (piezas...
# 2020Bl   <h3><p style="color:#d83030;"><b>Código Limatc...
# 3115     <h5 style="color: #ff0000;"><span style="color...
# 3205Be   <h3><p style="color:#ff0000;"><b>Código Limatc...
#
#         Attribute Name (pa_acabado) Attribute Value (pa_acabado)  \
# SKU
# 2009Oc                      Acabado                          NaN
# 2009Oce                     Acabado                          NaN
# 2020Bl                      Acabado                          NaN
# 3115                        Acabado                    Brillante
# 3205Be                      Acabado                          NaN
#
#         Attribute Name (pa_cantos_bordes) Attribute Value (pa_cantos_bordes)  \
# SKU
# 2009Oc                    Cantos o Bordes                                NaN
# 2009Oce                   Cantos o Bordes                                NaN
# 2020Bl                    Cantos o Bordes                                NaN
# 3115                      Cantos o Bordes                                NaN
# 3205Be                    Cantos o Bordes                                NaN
#
#         Attribute Name (pa_caras_destonalizado)  \
# SKU
# 2009Oc                    Caras o Destonalizado
# 2009Oce                   Caras o Destonalizado
# 2020Bl                    Caras o Destonalizado
# 3115                      Caras o Destonalizado
# 3205Be                    Caras o Destonalizado
#
#         Attribute Value (pa_caras_destonalizado)  \
# SKU
# 2009Oc                                       NaN
# 2009Oce                                      NaN
# 2020Bl                                       NaN
# 3115                                         NaN
# 3205Be                                       NaN
#
#         Attribute Name (pa_estetica_diseno)  \
# SKU
# 2009Oc                    Estética o Diseño
# 2009Oce                   Estética o Diseño
# 2020Bl                    Estética o Diseño
# 3115                      Estética o Diseño
# 3205Be                    Estética o Diseño
#
#         Attribute Value (pa_estetica_diseno) Attribute Name (pa_formato)  \
# SKU
# 2009Oc                                   NaN                     Formato
# 2009Oce                                  NaN                     Formato
# 2020Bl                                   NaN                     Formato
# 3115                                     NaN                     Formato
# 3205Be                                   NaN                     Formato
#
#         Attribute Value (pa_formato) Attribute Name (pa_m²_por_caja)  \
# SKU
# 2009Oc                           NaN                     M² por caja
# 2009Oce                          NaN                     M² por caja
# 2020Bl                         30x30                     M² por caja
# 3115             Pequeño hasta 35 cm                     M² por caja
# 3205Be           Pequeño hasta 35 cm                     M² por caja
#
#          Attribute Value (pa_m²_por_caja) Attribute Name (pa_marcas)  \
# SKU
# 2009Oc                                NaN                     Marcas
# 2009Oce                               NaN                     Marcas
# 2020Bl                                NaN                     Marcas
# 3115                                  NaN                     Marcas
# 3205Be                                NaN                     Marcas
#
#         Attribute Value (pa_marcas) Attribute Name (pa_terminacion)  \
# SKU
# 2009Oc                        Senso                     Terminación
# 2009Oce                       Senso                     Terminación
# 2020Bl                        Senso                     Terminación
# 3115                            NaN                     Terminación
# 3205Be                          NaN                     Terminación
#
#         Attribute Value (pa_terminacion)
# SKU
# 2009Oc                               NaN
# 2009Oce                              NaN
# 2020Bl                               NaN
# 3115                                 NaN
# 3205Be                               NaN

# %%
df2 = df1.drop(['Attribute Name (pa_acabado)', 'Attribute Value (pa_acabado)', 'Attribute Name (pa_cantos_bordes)', 'Attribute Value (pa_cantos_bordes)', 'Attribute Name (pa_caras_destonalizado)', 'Attribute Value (pa_caras_destonalizado)', 'Attribute Name (pa_estetica_diseno)', 'Attribute Value (pa_estetica_diseno)', 'Attribute Name (pa_formato)', 'Attribute Value (pa_formato)', 'Attribute Name (pa_m²_por_caja)', 'Attribute Value (pa_m²_por_caja)', 'Attribute Name (pa_marcas)', 'Attribute Value (pa_marcas)', 'Attribute Name (pa_terminacion)', 'Attribute Value (pa_terminacion)'], axis=1)

# %%
df3 = df2['Content'].str.replace('<br>', '_').str.replace('<h3>', '_').str.replace('<b>', '_')

# %%
df4 = df3["ANTIDESLIZANTE: SI"] = df2["Content"].str.contains("Antideslizante: SI")

# %%
df4[df3['Content'].str.contains('Antideslizante: SI')]

# %%
df4.to_excel("ANTIDESLIZANTE_SI.xlsx")
